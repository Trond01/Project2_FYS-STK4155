# %% [markdown]
# Part a) Write your own Stochastic Gradient Descent Code
#
# ### GD
# Create
# * [X] A plain gradient descent with a fixed learning rate which you tune
# * [X] Add momentum
# * [X] Compare convergence between the momentum model and one with fixed learning rate
#
# Repeat these steps for stochastic gradient descent with mini batches and a given number of epochs:
#
# ### SGD
# Create
# * [ ] A stochastic gradient descent with a fixed learning rate which you tune
# * [ ] Add momentum
# * [ ] Compare convergence between the momentum model and one with fixed learning rate
# Discuss
# * [ ] Discuss the results as functions of the various parameters (size of batches, number of epochs etc).
#
# ### Adagrad
#
# * [ ] Implement Adagrad without momentum for GD
# * [ ] Implement Adagrad with momentum for GD
# * [ ] Implement Adagrad without momentum for SGD
# * [ ] Implement Adagrad with momentum for SGD
#
# ### RMSprop
#
# * [ ] Implement RMSprop
#
# ### Adam
#
# * [ ] Implement Adaptive momement estimation
#
# ### Replace gradient
# * [ ] Choose Autograd or JAX
# * [ ] Replace analytical gradient with the chosen

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
import numpy as np
import matplotlib.pyplot as plt


# simple function
def f(x):
    return 1 + x + x**2

# analytical solution
def f_prime(x):
    return 1+2*x

# %%
# Forslag til annotate points -Jonatan
def annotate_points(x, y, color):
    for i, (xi, yi) in enumerate(zip(x, y)):
        plt.annotate(str(i), (xi, yi), textcoords="offset points", xytext=(0,5), ha='center', fontsize=12, color=color)

# %% [markdown]
# ### Forslag Trond og Eirik
#
# Vi skal erstatte matrise inverteringen i OLS og Ridge med GD og SGD. For OLS skal vi løse:
#
# $$
#     \hat{\beta}_{OLS}
#     = \textrm{arg}\min_{\beta\in\mathbb{R}^p} C_{OLS}(y-X\beta),
# $$
#
# $$
#     C_{OLS}(y-X\beta) = \frac{1}{N} \lVert y-X\beta \rVert_2^2.
# $$
#
# For Ridge løser vi:
#
# $$
#     \hat{\beta}_{Ridge}
#     = \textrm{arg}\min_{\beta\in\mathbb{R}^p} C_{Ridge}(y-X\beta),
# $$
#
# $$
#     C_{Ridge}(y-X\beta) = \frac{1}{N} \lVert y-X\beta \rVert_2^2 + \lambda \lVert \beta \rVert_2.
# $$
#
# For å benytte GD trenger vi analytiske uttrykk for gradienten til disse. Vi finner:
#
# $$
#     \nabla_{\beta}C_{OLS} = \frac{2}{N} X^T(X\beta - y),
# $$
#
# $$
#     \nabla_{\beta}C_{Ridge} = 2 \left( \frac{1}{N} X^T(X\beta - y) + \lambda\beta^T \right).
# $$

# %% [markdown]
# https://www.deeplearningbook.org/contents/optimization.html

# %%
import numpy as np
import jax.numpy as jnp
from jax import grad, nn
from matplotlib import pyplot as plt

# %%
# simple function
def f(x):
    return 1 + x + x**2

def feature_matrix(x, num_features):
    """
    x: array with x values
    num_features: the degree of polynomial 1+x+...+x^p

    returns:
    X: The feature matrix,a 2D numpy array with a column for each feature
    """

    return np.array([x**i for i in range(num_features)]).T[0]


def MSELoss(y, y_pred):
    """MSE loss of prediction array.

    Args:
        y (ndarray): Target values
        y_pred (ndarray): Predicted values

    Returns:
        float: MSE loss
    """
    return jnp.sum(jnp.power(y - y_pred, 2)) / y.shape[0]


def model(beta, X):
    return jnp.dot(X, beta)

# %%
def OLS_grad(beta, X, y):
    n = y.shape[0]
    return 2*(np.dot(X.T, ( model(beta, X) - y))) / n

def RIDGE_grad(beta, X, y, lam=0.01):
    n = y.shape[0]
    return 2*((np.dot(X.T, ( model(beta, X) - y)) / n) + lam*beta)

# %% [markdown]
# #### Gradient descent

# %%
def GD(grad_method, x, y, f(x)model, beta0, lr, n_epochs, gamma=None):
    """

    minimizes ...

    PARAMS
    grad_method : the function estimeating the gradient of the function to minimise
    x : function input
    y : target function output
    beta0 : initial point in the beta space 
    lr : learning rate, size of stept in direction of decrease
    n_epochs : number of iterations
    gamma : if given, perform with momentum parameter gamma
    
    RETURNS

    """

    loss_list = []

    # Make feature matrix
    X = feature_matrix(x, beta0.shape[0])

    # Initialise
    betas = [beta0]
    v = np.zeros_like(beta0) # initial v for momentum

    # Perform training
    for i in range(n_epochs):
        
        # Evaluate gradient at previous x
        grad = grad_method(betas[-1], X, y)

        #grad = derivative(betas[-1])
        loss_list.append(MSELoss(y, model(betas[-1], X)))
        # Perform step
        if gamma is not None:
            v = gamma * v + lr * grad
            betas.append( betas[-1] - v )
        else:
            betas.append( betas[-1] - lr * grad)
    
    # Return the found values of x 
    return betas, loss_list

# %%
def TODO_GD(grad_method, X, y, beta0 = None, test_cost_func = None, lr=0.01, n_epochs=50, gamma=None, store_all = False):
    """


    """

    # If test_cost_func:

    if store_all:
        betas = []

    # Make feature matrix
    X = feature_matrix(x, beta0.shape[0])

    # Initialise
    betas = [beta0]
    v = np.zeros_like(beta0) # initial v for momentum

    # Perform training
    for i in range(n_epochs):
        
        # Evaluate gradient at previous x
        grad = grad_method(betas[-1], X, y)

        #grad = derivative(betas[-1])
        loss_list.append(MSELoss(y, model(betas[-1], X)))
        # Perform step
        if gamma is not None:
            v = gamma * v + lr * grad
            betas.append( betas[-1] - v )
        else:
            betas.append( betas[-1] - lr * grad)
    
    # Return the found values of x 
    return betas, loss_list

# %% [markdown]
# #### Tuning the learning rate
#
# TODO: we should at some point find an efficient way to tone many parameters at the same time etc...

# %%
def lr_gamma_experiment(learning_rates, grad_method, x, y, beta0, n_epochs, gamma_values):
    """
    Plot the final error for fixed number of epochs and different learning rates
    for multiple gamma values on the same plot.
    """

    plt.figure(figsize=(10, 6))
    colors = plt.cm.jet(np.linspace(0, 1, len(gamma_values)))

    for idx, gamma in enumerate(gamma_values):
        final_errors = []
        for lr in learning_rates:
            betas, loss_list = GD(grad_method, x, y, beta0, lr, n_epochs, gamma)
            final_errors.append(loss_list[-1])

        plt.plot(learning_rates, final_errors, color=colors[idx], label=f'Gamma = {gamma}')
    
    plt.xscale('log')
    plt.ylim(-1, 8)
    plt.legend()
    plt.title('Learning Rate and Gamma Experiment')
    plt.show()

# Perform experiment
num_params = 5
num_points = 50

x = np.random.random((num_points, 1))
y = f(x)
beta0 = np.random.random((num_params, 1)) - 0.5

learning_rates = np.logspace(start=-6, stop=0, num=100)
gamma_values = [0.1, 0.5, 0.9, 0.99]
lr_gamma_experiment(learning_rates, OLS_grad, x, y, beta0, 100, gamma_values)

# %%
def lr_experiment(learning_rates, grad_method, x, y, beta0, n_epochs):
    """
    Plot the final error for fixed number of epochs and different learning rates
    """

    final_errors = []

    for lr in learning_rates:
        
        betas, loss_list = GD(grad_method, x, y, beta0, lr, n_epochs)

        final_errors.append(loss_list[-1])

    plt.xscale('log')
    # Set y-axis limits to [0, 2]
    plt.ylim(-1, 8)
    plt.plot(learning_rates, final_errors)

# Perform experiment
num_params = 5
num_points = 50


x = np.random.random((num_points, 1))
y = f(x)
beta0 = np.random.random((num_params, 1)) - 0.5

learning_rates = np.logspace(start=-6, stop=0, num=100)
lr_experiment(learning_rates, OLS_grad, x, y, beta0, 100)

# %% [markdown]
# #### Experiment with and without momentum

# %%
# Perform experiment
num_params = 5
num_points = 50


x = np.random.random((num_points, 1))
y = f(x)
print(x[-2])

beta0 = np.random.random((num_params, 1)) - 0.5

betas, loss_list = GD(OLS_grad, x, f(x), beta0, 0.01, 100)
betas, loss_list_2 = GD(OLS_grad, x, f(x), beta0, 0.01, 100, gamma=0.5)
beta = betas[-1]
# Out:
# [0.99421191]

# %%
plt.plot(loss_list, label="No Gamma")
plt.plot(loss_list_2, label="Gamma")
plt.legend()

# %% [markdown]
# #### Stochastic gradient descent

# %%
n = x.shape[0]

M = 5 # Size of minibatch
m = int(n / M) # number of minis

# Partition into minibatches
def random_partition(x, y, batch_size):
    batches = []
    n = y.shape[0]
    m = int(n / batch_size)
    for i in range(m):
        index = list(range(i*batch_size, (i+1)*batch_size))
        batches.append((x[index], y[index]))

    return batches


def SGD(grad_method, x, y, beta0, lr, n_epochs, batch_size, gamma=None):


    loss_list = []

    # Make feature matrix
    #X = feature_matrix(x, y, beta0.shape[0])

    batches = random_partition(x, y, batch_size)

    # Initialise
    betas = [beta0]
    v = np.zeros_like(beta0) # initial v for momentum

    # Number of batches
    n = y.shape[0]
    m = int(n / batch_size) 

    X_true = feature_matrix(x, beta0.shape[0])

    # Perform training
    for i in range(n_epochs):

        for j in range(m):
            k = np.random.randint(m)
            x_b, y_b = batches[k]

            X = feature_matrix(x_b, num_features=beta0.shape[0])

            # Evaluate gradient at previous x
            grad = OLS_grad(betas[-1], X, y_b)

            #grad = derivative(betas[-1])
            loss_list.append(MSELoss(y, model(betas[-1], X_true)))
            # Perform step
            if gamma is not None:
                v = gamma * v + lr * grad
                betas.append( betas[-1] - v )
            else:
                betas.append( betas[-1] - lr * grad)
    
    # Return the found values of x 
    return betas, loss_list

# %%
num_params = 5
num_points = 100

beta0 = np.random.random((num_params, 1))

x = np.random.random((num_points, 1))
y = f(x)


betas, loss_list = SGD(OLS_grad, x, y, beta0, batch_size=3, lr=0.01, n_epochs=100)

print(loss_list)
plt.plot(loss_list)
# Out:
# [Array(0.22897893, dtype=float32), Array(0.21692863, dtype=float32), Array(0.2103652, dtype=float32), Array(0.19626555, dtype=float32), Array(0.18638374, dtype=float32), Array(0.17400737, dtype=float32), Array(0.16437176, dtype=float32), Array(0.1533451, dtype=float32), Array(0.1432823, dtype=float32), Array(0.13443696, dtype=float32), Array(0.12856379, dtype=float32), Array(0.12017231, dtype=float32), Array(0.11279278, dtype=float32), Array(0.10997827, dtype=float32), Array(0.1058003, dtype=float32), Array(0.1013204, dtype=float32), Array(0.09441421, dtype=float32), Array(0.08949752, dtype=float32), Array(0.08405464, dtype=float32), Array(0.07883089, dtype=float32), Array(0.07469142, dtype=float32), Array(0.07138754, dtype=float32), Array(0.06756557, dtype=float32), Array(0.06629147, dtype=float32), Array(0.06281572, dtype=float32), Array(0.05957486, dtype=float32), Array(0.05558519, dtype=float32), Array(0.05435571, dtype=float32), Array(0.05158104, dtype=float32), Array(0.04830225, dtype=float32), Array(0.04638164, dtype=float32), Array(0.0436608, dtype=float32), Array(0.04237447, dtype=float32), Array(0.0396292, dtype=float32), Array(0.03879457, dtype=float32), Array(0.03648772, dtype=float32), Array(0.0367076, dtype=float32), Array(0.03528537, dtype=float32), Array(0.03330528, dtype=float32), Array(0.03178062, dtype=float32), Array(0.03025723, dtype=float32), Array(0.02845574, dtype=float32), Array(0.02646653, dtype=float32), Array(0.02587187, dtype=float32), Array(0.02633102, dtype=float32), Array(0.02544838, dtype=float32), Array(0.02416524, dtype=float32), Array(0.02396985, dtype=float32), Array(0.02263319, dtype=float32), Array(0.02139885, dtype=float32), Array(0.02058147, dtype=float32), Array(0.01985462, dtype=float32), Array(0.0191325, dtype=float32), Array(0.01818942, dtype=float32), Array(0.01757962, dtype=float32), Array(0.01727514, dtype=float32), Array(0.01678699, dtype=float32), Array(0.01729348, dtype=float32), Array(0.01701901, dtype=float32), Array(0.01623943, dtype=float32), Array(0.01557048, dtype=float32), Array(0.01515685, dtype=float32), Array(0.01524187, dtype=float32), Array(0.01463757, dtype=float32), Array(0.0143748, dtype=float32), Array(0.01399319, dtype=float32), Array(0.01356927, dtype=float32), Array(0.01326654, dtype=float32), Array(0.01343833, dtype=float32), Array(0.0131319, dtype=float32), Array(0.01309352, dtype=float32), Array(0.01282836, dtype=float32), Array(0.01298121, dtype=float32), Array(0.0126357, dtype=float32), Array(0.01244107, dtype=float32), Array(0.01222456, dtype=float32), Array(0.01220775, dtype=float32), Array(0.01237864, dtype=float32), Array(0.01205523, dtype=float32), Array(0.01210492, dtype=float32), Array(0.01191783, dtype=float32), Array(0.01174275, dtype=float32), Array(0.01158115, dtype=float32), Array(0.01137505, dtype=float32), Array(0.01130588, dtype=float32), Array(0.01128247, dtype=float32), Array(0.01113949, dtype=float32), Array(0.0110284, dtype=float32), Array(0.01116224, dtype=float32), Array(0.01106648, dtype=float32), Array(0.01095911, dtype=float32), Array(0.01095534, dtype=float32), Array(0.01077729, dtype=float32), Array(0.01063894, dtype=float32), Array(0.01060309, dtype=float32), Array(0.01052379, dtype=float32), Array(0.01047223, dtype=float32), Array(0.01037689, dtype=float32), Array(0.01034919, dtype=float32), Array(0.010318, dtype=float32), Array(0.01028894, dtype=float32), Array(0.01032239, dtype=float32), Array(0.01031346, dtype=float32), Array(0.01040094, dtype=float32), Array(0.01033863, dtype=float32), Array(0.01028265, dtype=float32), Array(0.01025714, dtype=float32), Array(0.01020275, dtype=float32), Array(0.01019921, dtype=float32), Array(0.01018358, dtype=float32), Array(0.0101847, dtype=float32), Array(0.01018548, dtype=float32), Array(0.01018902, dtype=float32), Array(0.01017343, dtype=float32), Array(0.01016638, dtype=float32), Array(0.01017056, dtype=float32), Array(0.01015465, dtype=float32), Array(0.01014786, dtype=float32), Arr ...

# %%
print(loss_list)
plt.plot(loss_list)
# Out:
# [Array(0.22897893, dtype=float32), Array(0.21692863, dtype=float32), Array(0.2103652, dtype=float32), Array(0.19626555, dtype=float32), Array(0.18638374, dtype=float32), Array(0.17400737, dtype=float32), Array(0.16437176, dtype=float32), Array(0.1533451, dtype=float32), Array(0.1432823, dtype=float32), Array(0.13443696, dtype=float32), Array(0.12856379, dtype=float32), Array(0.12017231, dtype=float32), Array(0.11279278, dtype=float32), Array(0.10997827, dtype=float32), Array(0.1058003, dtype=float32), Array(0.1013204, dtype=float32), Array(0.09441421, dtype=float32), Array(0.08949752, dtype=float32), Array(0.08405464, dtype=float32), Array(0.07883089, dtype=float32), Array(0.07469142, dtype=float32), Array(0.07138754, dtype=float32), Array(0.06756557, dtype=float32), Array(0.06629147, dtype=float32), Array(0.06281572, dtype=float32), Array(0.05957486, dtype=float32), Array(0.05558519, dtype=float32), Array(0.05435571, dtype=float32), Array(0.05158104, dtype=float32), Array(0.04830225, dtype=float32), Array(0.04638164, dtype=float32), Array(0.0436608, dtype=float32), Array(0.04237447, dtype=float32), Array(0.0396292, dtype=float32), Array(0.03879457, dtype=float32), Array(0.03648772, dtype=float32), Array(0.0367076, dtype=float32), Array(0.03528537, dtype=float32), Array(0.03330528, dtype=float32), Array(0.03178062, dtype=float32), Array(0.03025723, dtype=float32), Array(0.02845574, dtype=float32), Array(0.02646653, dtype=float32), Array(0.02587187, dtype=float32), Array(0.02633102, dtype=float32), Array(0.02544838, dtype=float32), Array(0.02416524, dtype=float32), Array(0.02396985, dtype=float32), Array(0.02263319, dtype=float32), Array(0.02139885, dtype=float32), Array(0.02058147, dtype=float32), Array(0.01985462, dtype=float32), Array(0.0191325, dtype=float32), Array(0.01818942, dtype=float32), Array(0.01757962, dtype=float32), Array(0.01727514, dtype=float32), Array(0.01678699, dtype=float32), Array(0.01729348, dtype=float32), Array(0.01701901, dtype=float32), Array(0.01623943, dtype=float32), Array(0.01557048, dtype=float32), Array(0.01515685, dtype=float32), Array(0.01524187, dtype=float32), Array(0.01463757, dtype=float32), Array(0.0143748, dtype=float32), Array(0.01399319, dtype=float32), Array(0.01356927, dtype=float32), Array(0.01326654, dtype=float32), Array(0.01343833, dtype=float32), Array(0.0131319, dtype=float32), Array(0.01309352, dtype=float32), Array(0.01282836, dtype=float32), Array(0.01298121, dtype=float32), Array(0.0126357, dtype=float32), Array(0.01244107, dtype=float32), Array(0.01222456, dtype=float32), Array(0.01220775, dtype=float32), Array(0.01237864, dtype=float32), Array(0.01205523, dtype=float32), Array(0.01210492, dtype=float32), Array(0.01191783, dtype=float32), Array(0.01174275, dtype=float32), Array(0.01158115, dtype=float32), Array(0.01137505, dtype=float32), Array(0.01130588, dtype=float32), Array(0.01128247, dtype=float32), Array(0.01113949, dtype=float32), Array(0.0110284, dtype=float32), Array(0.01116224, dtype=float32), Array(0.01106648, dtype=float32), Array(0.01095911, dtype=float32), Array(0.01095534, dtype=float32), Array(0.01077729, dtype=float32), Array(0.01063894, dtype=float32), Array(0.01060309, dtype=float32), Array(0.01052379, dtype=float32), Array(0.01047223, dtype=float32), Array(0.01037689, dtype=float32), Array(0.01034919, dtype=float32), Array(0.010318, dtype=float32), Array(0.01028894, dtype=float32), Array(0.01032239, dtype=float32), Array(0.01031346, dtype=float32), Array(0.01040094, dtype=float32), Array(0.01033863, dtype=float32), Array(0.01028265, dtype=float32), Array(0.01025714, dtype=float32), Array(0.01020275, dtype=float32), Array(0.01019921, dtype=float32), Array(0.01018358, dtype=float32), Array(0.0101847, dtype=float32), Array(0.01018548, dtype=float32), Array(0.01018902, dtype=float32), Array(0.01017343, dtype=float32), Array(0.01016638, dtype=float32), Array(0.01017056, dtype=float32), Array(0.01015465, dtype=float32), Array(0.01014786, dtype=float32), Arr ...

# %%
# Repeat these steps for stochastic gradient descent with mini batches and a given number of epochs. 
#Use a tunable learning rate as discussed in the lectures from week 39. 
#Discuss the results as functions of the various parameters (size of batches, number of epochs etc)

# %% [markdown]
# #### Adagrad
#
# Adagrad is the method of scaling down the learning rate as we go...
#
# We initialise some learning rate $\eta$

# %% [markdown]
# <img src="image-20231014-152824.png" width="" align="" />

# %%
def SGD_adagrad(grad_method, x, y, beta0, lr, n_epochs, batch_size, gamma=None, delta = 1e-8):

    # Initial value for the tuneable learning rate
    eta = lr

    # Including AdaGrad parameter to avoid possible division by zero
    delta  = 1e-8

    # Initialise
    loss_list = []
    betas = [beta0]
    v = np.zeros_like(beta0) # initial v for momentum

    # Partition
    batches = random_partition(x, y, batch_size)

    # Number of batches
    n = y.shape[0]
    m = int(n / batch_size) 

    # For measuring loss
    X_true = feature_matrix(x, beta0.shape[0])

    for epoch in range(n_epochs):

        # reset accumulation variable
        r = 0

        for i in range(m):

            # Draw a batch and make feature matrix
            k = np.random.randint(m)
            x_b, y_b = batches[k]

            X = feature_matrix(x_b, num_features=beta0.shape[0])

            # Compute gradient of this sub-epoch
            gradients = grad_method(betas[-1], X, y_b)
    
            # Add to total gradient                
            r += gradients*gradients

            # Adagrad scaling, learning rate is scaled down, append new result
            lr_times_grad = eta/(delta+np.sqrt(r)) * gradients

            # Perform step
            if gamma is not None:
                v = gamma * v + lr_times_grad
                betas.append( betas[-1] - v )
            else:
                betas.append( betas[-1] - lr_times_grad)

            # Add loss
            loss_list.append(MSELoss(y, model(betas[-1], X_true)))

    
    # Return the found values of x 
    return betas, loss_list

num_params = 5
num_points = 100

beta0 = np.random.random((num_params, 1))

x = np.random.random((num_points, 1))
y = f(x)

betas, loss_list = SGD_adagrad(OLS_grad, x, y, beta0, batch_size=10, lr=0.01, n_epochs=100)

print(loss_list)
plt.plot(loss_list)
plt.xlabel("Training step")
plt.ylabel("MSE")
plt.show()
# Out:
# [Array(0.19539109, dtype=float32), Array(0.18193588, dtype=float32), Array(0.17124619, dtype=float32), Array(0.16148205, dtype=float32), Array(0.15352982, dtype=float32), Array(0.14620571, dtype=float32), Array(0.14069277, dtype=float32), Array(0.13735472, dtype=float32), Array(0.13223144, dtype=float32), Array(0.1271594, dtype=float32), Array(0.11154709, dtype=float32), Array(0.10162517, dtype=float32), Array(0.09453226, dtype=float32), Array(0.08968864, dtype=float32), Array(0.0847859, dtype=float32), Array(0.08074494, dtype=float32), Array(0.07706559, dtype=float32), Array(0.07452209, dtype=float32), Array(0.07268566, dtype=float32), Array(0.07052562, dtype=float32), Array(0.06102696, dtype=float32), Array(0.05462422, dtype=float32), Array(0.05169506, dtype=float32), Array(0.04800497, dtype=float32), Array(0.04529413, dtype=float32), Array(0.04323862, dtype=float32), Array(0.04112511, dtype=float32), Array(0.04019652, dtype=float32), Array(0.03932804, dtype=float32), Array(0.03851203, dtype=float32), Array(0.03468093, dtype=float32), Array(0.03225191, dtype=float32), Array(0.03072495, dtype=float32), Array(0.03025168, dtype=float32), Array(0.02943802, dtype=float32), Array(0.02881526, dtype=float32), Array(0.02809151, dtype=float32), Array(0.02754685, dtype=float32), Array(0.02725428, dtype=float32), Array(0.02665846, dtype=float32), Array(0.02492732, dtype=float32), Array(0.02301961, dtype=float32), Array(0.02298086, dtype=float32), Array(0.02147207, dtype=float32), Array(0.02138634, dtype=float32), Array(0.02101703, dtype=float32), Array(0.01985709, dtype=float32), Array(0.01896468, dtype=float32), Array(0.01857081, dtype=float32), Array(0.01806981, dtype=float32), Array(0.01615742, dtype=float32), Array(0.01552314, dtype=float32), Array(0.01451512, dtype=float32), Array(0.01405564, dtype=float32), Array(0.01349812, dtype=float32), Array(0.01280453, dtype=float32), Array(0.01252524, dtype=float32), Array(0.01238705, dtype=float32), Array(0.01207465, dtype=float32), Array(0.01152214, dtype=float32), Array(0.01017855, dtype=float32), Array(0.00974272, dtype=float32), Array(0.00957269, dtype=float32), Array(0.00919017, dtype=float32), Array(0.008906, dtype=float32), Array(0.00884595, dtype=float32), Array(0.00847729, dtype=float32), Array(0.00855392, dtype=float32), Array(0.00832791, dtype=float32), Array(0.00810809, dtype=float32), Array(0.00962813, dtype=float32), Array(0.00808649, dtype=float32), Array(0.00779073, dtype=float32), Array(0.00789144, dtype=float32), Array(0.00773075, dtype=float32), Array(0.00799742, dtype=float32), Array(0.00740637, dtype=float32), Array(0.00713792, dtype=float32), Array(0.0071345, dtype=float32), Array(0.0070082, dtype=float32), Array(0.00765971, dtype=float32), Array(0.00688312, dtype=float32), Array(0.00691854, dtype=float32), Array(0.00677448, dtype=float32), Array(0.00653281, dtype=float32), Array(0.00656051, dtype=float32), Array(0.00651819, dtype=float32), Array(0.00659585, dtype=float32), Array(0.00626975, dtype=float32), Array(0.00632808, dtype=float32), Array(0.0062606, dtype=float32), Array(0.00595689, dtype=float32), Array(0.00606909, dtype=float32), Array(0.00576621, dtype=float32), Array(0.00562583, dtype=float32), Array(0.00576437, dtype=float32), Array(0.0055094, dtype=float32), Array(0.00540798, dtype=float32), Array(0.00536819, dtype=float32), Array(0.00547136, dtype=float32), Array(0.0054542, dtype=float32), Array(0.00519895, dtype=float32), Array(0.00512995, dtype=float32), Array(0.00512432, dtype=float32), Array(0.00512138, dtype=float32), Array(0.00507996, dtype=float32), Array(0.0053396, dtype=float32), Array(0.00515646, dtype=float32), Array(0.00504809, dtype=float32), Array(0.00487199, dtype=float32), Array(0.00508385, dtype=float32), Array(0.00469755, dtype=float32), Array(0.00465856, dtype=float32), Array(0.00486392, dtype=float32), Array(0.0052926, dtype=float32), Array(0.00527423, dtype=float32), Array(0.00458705, dtype=float32), Array(0.00467819, dtype=float32) ...

# %% [markdown]
# #### RMS prop

# %%
def SGD_RMS_prop(grad_method, x, y, beta0, lr, n_epochs, batch_size, gamma=0, delta = 1e-8):

    eta = 0.01

    # Including AdaGrad parameter to avoid possible division by zero
    delta  = 1e-8

    # Accumulation variable
    rho = 0.05

    # Initialise
    loss_list = []
    betas = [beta0]
    v = np.zeros_like(beta0) # initial v for momentum

    # Partition
    batches = random_partition(x, y, batch_size)

    # Number of batches
    n = y.shape[0]
    m = int(n / batch_size) 

    # For measuring loss
    X_true = feature_matrix(x, beta0.shape[0])

    # Perform training
    for i in range(n_epochs):
        Giter = 0

        # Iterate over the batches
        for j in range(m):
            k = np.random.randint(m)
            x_b, y_b = batches[k]

            X = feature_matrix(x_b, num_features=beta0.shape[0])

            # Evaluate gradient at previous x
            grad = (1.0/batch_size)*grad_method(betas[-1], X, y_b)

            Giter = (rho*Giter+(1-rho)*grad*grad)
            #grad = derivative(betas[-1])

            loss_list.append(MSELoss(y, model(betas[-1], X_true)))
            
            update = grad*eta/(delta+np.sqrt(Giter))
            # Perform step
            v = gamma * v + update
            betas.append( betas[-1] - v )
        
    # Return the found values of x 
    return betas, loss_list

# %%
num_params = 5
num_points = 100

beta0 = np.random.random((num_params, 1))

x = np.random.random((num_points, 1))
y = f(x)

betas, loss_list = SGD_RMS_prop(OLS_grad, x, y, beta0, batch_size=10, lr=0.01, n_epochs=100)

print(loss_list)
plt.plot(loss_list)
plt.xlabel("Training step")
plt.ylabel("MSE")
plt.show()
# Out:
# [Array(0.2541217, dtype=float32), Array(0.22843757, dtype=float32), Array(0.20486757, dtype=float32), Array(0.1824699, dtype=float32), Array(0.16147727, dtype=float32), Array(0.14177965, dtype=float32), Array(0.12336905, dtype=float32), Array(0.10637037, dtype=float32), Array(0.0905921, dtype=float32), Array(0.07635389, dtype=float32), Array(0.06327971, dtype=float32), Array(0.05103438, dtype=float32), Array(0.04049036, dtype=float32), Array(0.03124153, dtype=float32), Array(0.02326516, dtype=float32), Array(0.01676882, dtype=float32), Array(0.0113397, dtype=float32), Array(0.00744369, dtype=float32), Array(0.00460202, dtype=float32), Array(0.00309319, dtype=float32), Array(0.00242582, dtype=float32), Array(0.00251888, dtype=float32), Array(0.0021721, dtype=float32), Array(0.0022176, dtype=float32), Array(0.00197545, dtype=float32), Array(0.00210223, dtype=float32), Array(0.00174975, dtype=float32), Array(0.00131693, dtype=float32), Array(0.00204983, dtype=float32), Array(0.00108256, dtype=float32), Array(0.00121677, dtype=float32), Array(0.00135078, dtype=float32), Array(0.00118388, dtype=float32), Array(0.00093717, dtype=float32), Array(0.00122522, dtype=float32), Array(0.00082859, dtype=float32), Array(0.00158188, dtype=float32), Array(0.0008067, dtype=float32), Array(0.00101534, dtype=float32), Array(0.0007786, dtype=float32), Array(0.00156192, dtype=float32), Array(0.00077158, dtype=float32), Array(0.00080136, dtype=float32), Array(0.00082637, dtype=float32), Array(0.00091055, dtype=float32), Array(0.00065444, dtype=float32), Array(0.00082591, dtype=float32), Array(0.00063461, dtype=float32), Array(0.00055483, dtype=float32), Array(0.00085816, dtype=float32), Array(0.00059549, dtype=float32), Array(0.0008615, dtype=float32), Array(0.00058056, dtype=float32), Array(0.00062317, dtype=float32), Array(0.00086617, dtype=float32), Array(0.00058605, dtype=float32), Array(0.00069139, dtype=float32), Array(0.00050784, dtype=float32), Array(0.00129476, dtype=float32), Array(0.00050755, dtype=float32), Array(0.00048179, dtype=float32), Array(0.00101286, dtype=float32), Array(0.00048166, dtype=float32), Array(0.00073557, dtype=float32), Array(0.00055675, dtype=float32), Array(0.00050941, dtype=float32), Array(0.00080008, dtype=float32), Array(0.00048429, dtype=float32), Array(0.000704, dtype=float32), Array(0.00052917, dtype=float32), Array(0.00064377, dtype=float32), Array(0.0005719, dtype=float32), Array(0.00063869, dtype=float32), Array(0.0005676, dtype=float32), Array(0.00053479, dtype=float32), Array(0.00052406, dtype=float32), Array(0.00066377, dtype=float32), Array(0.00052703, dtype=float32), Array(0.00052528, dtype=float32), Array(0.00057499, dtype=float32), Array(0.00058072, dtype=float32), Array(0.00057717, dtype=float32), Array(0.00056788, dtype=float32), Array(0.00045334, dtype=float32), Array(0.00074045, dtype=float32), Array(0.00046115, dtype=float32), Array(0.00066657, dtype=float32), Array(0.00048765, dtype=float32), Array(0.00062541, dtype=float32), Array(0.00048768, dtype=float32), Array(0.00059507, dtype=float32), Array(0.00050748, dtype=float32), Array(0.00046222, dtype=float32), Array(0.00067805, dtype=float32), Array(0.0004671, dtype=float32), Array(0.00052358, dtype=float32), Array(0.00043805, dtype=float32), Array(0.00071599, dtype=float32), Array(0.0004039, dtype=float32), Array(0.00081201, dtype=float32), Array(0.00040742, dtype=float32), Array(0.00081472, dtype=float32), Array(0.00040698, dtype=float32), Array(0.00061686, dtype=float32), Array(0.00040558, dtype=float32), Array(0.00074631, dtype=float32), Array(0.0003924, dtype=float32), Array(0.00075938, dtype=float32), Array(0.00039833, dtype=float32), Array(0.0005954, dtype=float32), Array(0.00039375, dtype=float32), Array(0.00073057, dtype=float32), Array(0.00039305, dtype=float32), Array(0.00036911, dtype=float32), Array(0.00067271, dtype=float32), Array(0.00037685, dtype=float32), Array(0.00064443, dtype=float32), Array(0.0003726, dtype=float32), Array ...

# %%
# Add RMSprop and Adam to your library of methods for tuning the learning rate.

# %% [markdown]
# #### Adam

# %% [markdown]
# <img src="image-20231014-160214.png" width="" align="" />

# %%
def SGD_adam(grad_method, x, y, beta0, n_epochs, batch_size, lr=0.01, gamma=0.0, delta = 1e-8, beta1=0.9, beta2=0.99):

    # Initial value for learning rate
    eta = lr

    # Including AdaGrad parameter to avoid possible division by zero
    delta  = 1e-8

    # Initialise
    loss_list = []
    betas = [beta0]
    v = np.zeros_like(beta0) # initial v for momentum

    # Partition
    batches = random_partition(x, y, batch_size)
    # Number of batches
    n = y.shape[0]
    m = int(n / batch_size) 

    # For measuring loss
    X_true = feature_matrix(x, beta0.shape[0])

    for epoch in range(n_epochs):

        # Accumulation variable
        s = 0 # first moment
        r = 0 # second moment

        for i in range(m):

            # Draw a batch and make feature matrix
            k = np.random.randint(m)
            x_b, y_b = batches[k]
            X = feature_matrix(x_b, num_features=beta0.shape[0])

            # Compute gradient of this sub-epoch
            gradients = grad_method(betas[-1], X, y_b)

            # Accumulate
            s = beta1*s + (1-beta1)*gradients
            r = beta2*r + (1-beta2)*gradients*gradients

            first_term = s/(1-beta1**(epoch+1))            
            second_term = r/(1-beta2**(epoch+1))

            # Adam scaling
            update = eta*first_term / (np.sqrt(second_term) + delta) # safe division with delta

            v = gamma * v + update
            # Perform step
            betas.append( betas[-1] - v)

            # Add loss
            loss_list.append(MSELoss(y, model(betas[-1], X_true)))
    
    # Return the found values of x 
    return betas, loss_list

num_params = 5
num_points = 100

beta0 = np.random.random((num_params, 1))

x = np.random.random((num_points, 1))
y = f(x)

betas, loss_list = SGD_adam(OLS_grad, x, y, beta0, batch_size=10, n_epochs=100)

print(loss_list)
plt.plot(loss_list)
plt.xlabel("Training step")
plt.ylabel("MSE")
plt.show()
# Out:
# [Array(0.10108944, dtype=float32), Array(0.09309727, dtype=float32), Array(0.08642229, dtype=float32), Array(0.08032373, dtype=float32), Array(0.07488181, dtype=float32), Array(0.07077963, dtype=float32), Array(0.06863498, dtype=float32), Array(0.06607842, dtype=float32), Array(0.06158352, dtype=float32), Array(0.05620058, dtype=float32), Array(0.05431167, dtype=float32), Array(0.05203366, dtype=float32), Array(0.04964477, dtype=float32), Array(0.04725549, dtype=float32), Array(0.04438085, dtype=float32), Array(0.04130089, dtype=float32), Array(0.03853469, dtype=float32), Array(0.03607489, dtype=float32), Array(0.03368106, dtype=float32), Array(0.03130623, dtype=float32), Array(0.03073568, dtype=float32), Array(0.02979012, dtype=float32), Array(0.02981479, dtype=float32), Array(0.02956215, dtype=float32), Array(0.02803898, dtype=float32), Array(0.02600545, dtype=float32), Array(0.02375867, dtype=float32), Array(0.02177668, dtype=float32), Array(0.02003054, dtype=float32), Array(0.01839284, dtype=float32), Array(0.01734103, dtype=float32), Array(0.01608247, dtype=float32), Array(0.01520804, dtype=float32), Array(0.01431444, dtype=float32), Array(0.01360571, dtype=float32), Array(0.01291718, dtype=float32), Array(0.01233097, dtype=float32), Array(0.0116392, dtype=float32), Array(0.01114625, dtype=float32), Array(0.01088698, dtype=float32), Array(0.0118709, dtype=float32), Array(0.01186268, dtype=float32), Array(0.01186047, dtype=float32), Array(0.01136405, dtype=float32), Array(0.01037205, dtype=float32), Array(0.00907985, dtype=float32), Array(0.00816244, dtype=float32), Array(0.00751585, dtype=float32), Array(0.00735989, dtype=float32), Array(0.00746774, dtype=float32), Array(0.00715653, dtype=float32), Array(0.00730752, dtype=float32), Array(0.00813772, dtype=float32), Array(0.00831169, dtype=float32), Array(0.00797336, dtype=float32), Array(0.0074365, dtype=float32), Array(0.00701004, dtype=float32), Array(0.00683774, dtype=float32), Array(0.00701624, dtype=float32), Array(0.00747648, dtype=float32), Array(0.00693174, dtype=float32), Array(0.00670329, dtype=float32), Array(0.00668319, dtype=float32), Array(0.00665661, dtype=float32), Array(0.00661955, dtype=float32), Array(0.00670485, dtype=float32), Array(0.00659741, dtype=float32), Array(0.00637577, dtype=float32), Array(0.00622333, dtype=float32), Array(0.00631035, dtype=float32), Array(0.00635028, dtype=float32), Array(0.00613956, dtype=float32), Array(0.00604805, dtype=float32), Array(0.00584341, dtype=float32), Array(0.0059342, dtype=float32), Array(0.00598789, dtype=float32), Array(0.0061444, dtype=float32), Array(0.00654692, dtype=float32), Array(0.00645279, dtype=float32), Array(0.00593127, dtype=float32), Array(0.00549991, dtype=float32), Array(0.00540538, dtype=float32), Array(0.00535585, dtype=float32), Array(0.00548145, dtype=float32), Array(0.00573415, dtype=float32), Array(0.00555313, dtype=float32), Array(0.00551262, dtype=float32), Array(0.00522769, dtype=float32), Array(0.00495698, dtype=float32), Array(0.00486498, dtype=float32), Array(0.00487582, dtype=float32), Array(0.00487074, dtype=float32), Array(0.00460054, dtype=float32), Array(0.00447101, dtype=float32), Array(0.00441666, dtype=float32), Array(0.00447494, dtype=float32), Array(0.00451916, dtype=float32), Array(0.00433963, dtype=float32), Array(0.00412726, dtype=float32), Array(0.00393721, dtype=float32), Array(0.00382865, dtype=float32), Array(0.00375862, dtype=float32), Array(0.00367861, dtype=float32), Array(0.00365114, dtype=float32), Array(0.00365962, dtype=float32), Array(0.0035238, dtype=float32), Array(0.00345739, dtype=float32), Array(0.00338508, dtype=float32), Array(0.00329828, dtype=float32), Array(0.00324608, dtype=float32), Array(0.00330709, dtype=float32), Array(0.00333355, dtype=float32), Array(0.00314158, dtype=float32), Array(0.00312938, dtype=float32), Array(0.00313664, dtype=float32), Array(0.00320401, dtype=float32), Array(0.00313657, dtype=float32), Array(0.00293949, dtype=flo ...

# %%
def Ridge_loss_method(lam, model):
    return (lambda beta, X, y : Ridge_Loss(beta, X, y, model, lam))

def Ridge_Loss(beta, X, y, model, lam=0.01):
    return MSELoss(model(beta, X), y) + jnp.sum(jnp.power(beta, 2))*(lam/(2*jnp.size(y)))


def MSELoss_method(model):
    return (lambda beta, X, y : MSELoss(model(beta, X), y))


def MSELoss(y, y_pred):
    """MSE loss of prediction array.

    Args:
        y (ndarray): Target values
        y_pred (ndarray): Predicted values

    Returns:
        float: MSE loss
    """
    return jnp.sum(jnp.power(y - y_pred, 2)) / y.shape[0]

# %%
def jax_loss_grad(loss_func):
    return grad(loss_func)


def model_2(beta, X):
    X_1 = jnp.dot(X, beta[0])
    X_1 = nn.sigmoid(X_1)
    X_2 = jnp.dot(X_1, beta[1])
    return X_2



Ridge_grad_jax = jax_loss_grad(loss_func=Ridge_loss_method(0.1, model=model))
OLS_grad_jax = jax_loss_grad(loss_func=MSELoss_method(model))


num_params = 5
middle_layer  = 10
num_points = 100

beta_try = [np.random.random((num_params, middle_layer)), np.random.random((middle_layer, 1))]



beta0 = np.random.random((num_params, 1))
x = np.random.random((num_points, 1))
y = f(x)

#print(test_grad(beta0, feature_matrix(X, num_params), y))

betas, loss_list = GD(OLS_grad_jax, x, y, beta0, lr=0.01, n_epochs=100, gamma=0.88)

print(loss_list)
plt.plot(loss_list)
plt.title("GD")
plt.xlabel("Training step")
plt.ylabel("MSE")
plt.show()



betas, loss_list = SGD(OLS_grad_jax, x, y, beta0, batch_size=10, lr=0.01, n_epochs=100, gamma=0.99)

print(loss_list)
plt.plot(loss_list)
plt.title("SGD")
plt.xlabel("Training step")
plt.ylabel("MSE")
plt.show()

betas, loss_list = SGD_adagrad(OLS_grad_jax, x, y, beta0, batch_size=10, lr=0.01, gamma=0.99,delta=0.001, n_epochs=100)

print(loss_list)
plt.plot(loss_list)
plt.title("Adagrad")
plt.xlabel("Training step")
plt.ylabel("MSE")
plt.show()


betas, loss_list = SGD_RMS_prop(OLS_grad_jax, x, y, beta0, batch_size=10, lr=0.01, gamma=0.99,delta=0.001, n_epochs=100)

print(loss_list)
plt.plot(loss_list)
plt.title("RMS_prop")
plt.xlabel("Training step")
plt.ylabel("MSE")
plt.show()


betas, loss_list = SGD_adam(Ridge_grad_jax, x, y, beta0, lr=0.01, batch_size=10, gamma=0.99,delta=0.001, n_epochs=100)

print(loss_list)
plt.plot(loss_list)
plt.title("Adam")
plt.xlabel("Training step")
plt.ylabel("MSE")
plt.show()
# Out:
# [Array(0.9044524, dtype=float32), Array(0.85577995, dtype=float32), Array(0.76951444, dtype=float32), Array(0.6589603, dtype=float32), Array(0.53760654, dtype=float32), Array(0.41753566, dtype=float32), Array(0.30835357, dtype=float32), Array(0.21664196, dtype=float32), Array(0.14587414, dtype=float32), Array(0.09669856, dtype=float32), Array(0.06747524, dtype=float32), Array(0.05494776, dtype=float32), Array(0.05494559, dtype=float32), Array(0.0630319, dtype=float32), Array(0.07503663, dtype=float32), Array(0.08744202, dtype=float32), Array(0.0976105, dtype=float32), Array(0.10386508, dtype=float32), Array(0.10544692, dtype=float32), Array(0.10238165, dtype=float32), Array(0.09529026, dtype=float32), Array(0.08517767, dtype=float32), Array(0.07322702, dtype=float32), Array(0.06062173, dtype=float32), Array(0.0484081, dtype=float32), Array(0.03740488, dtype=float32), Array(0.02815877, dtype=float32), Array(0.02094061, dtype=float32), Array(0.01577355, dtype=float32), Array(0.01248243, dtype=float32), Array(0.0107546, dtype=float32), Array(0.01020238, dtype=float32), Array(0.01042008, dtype=float32), Array(0.01103047, dtype=float32), Array(0.01171779, dtype=float32), Array(0.0122468, dtype=float32), Array(0.01246874, dtype=float32), Array(0.01231664, dtype=float32), Array(0.01179274, dtype=float32), Array(0.01095123, dtype=float32), Array(0.00987937, dtype=float32), Array(0.00867919, dtype=float32), Array(0.00745191, dtype=float32), Array(0.00628603, dtype=float32), Array(0.00524955, dtype=float32), Array(0.00438643, dtype=float32), Array(0.00371645, dtype=float32), Array(0.00323792, dtype=float32), Array(0.00293223, dtype=float32), Array(0.00276921, dtype=float32), Array(0.00271276, dtype=float32), Array(0.00272575, dtype=float32), Array(0.00277409, dtype=float32), Array(0.00282952, dtype=float32), Array(0.00287117, dtype=float32), Array(0.002886, dtype=float32), Array(0.00286825, dtype=float32), Array(0.0028183, dtype=float32), Array(0.00274106, dtype=float32), Array(0.00264428, dtype=float32), Array(0.00253696, dtype=float32), Array(0.00242792, dtype=float32), Array(0.00232479, dtype=float32), Array(0.00223338, dtype=float32), Array(0.00215736, dtype=float32), Array(0.00209826, dtype=float32), Array(0.00205576, dtype=float32), Array(0.00202805, dtype=float32), Array(0.00201239, dtype=float32), Array(0.00200554, dtype=float32), Array(0.00200421, dtype=float32), Array(0.00200542, dtype=float32), Array(0.00200672, dtype=float32), Array(0.00200635, dtype=float32), Array(0.00200322, dtype=float32), Array(0.00199691, dtype=float32), Array(0.00198751, dtype=float32), Array(0.00197551, dtype=float32), Array(0.00196166, dtype=float32), Array(0.00194677, dtype=float32), Array(0.00193164, dtype=float32), Array(0.00191697, dtype=float32), Array(0.00190326, dtype=float32), Array(0.00189084, dtype=float32), Array(0.00187985, dtype=float32), Array(0.00187025, dtype=float32), Array(0.00186189, dtype=float32), Array(0.00185454, dtype=float32), Array(0.00184789, dtype=float32), Array(0.00184168, dtype=float32), Array(0.00183565, dtype=float32), Array(0.00182959, dtype=float32), Array(0.00182336, dtype=float32), Array(0.00181687, dtype=float32), Array(0.0018101, dtype=float32), Array(0.00180305, dtype=float32), Array(0.00179578, dtype=float32), Array(0.00178837, dtype=float32), Array(0.00178087, dtype=float32), Array(0.00177338, dtype=float32)]
# [Array(0.9044524, dtype=float32), Array(0.8524304, dtype=float32), Array(0.7575003, dtype=float32), Array(0.6314548, dtype=float32), Array(0.4893718, dtype=float32), Array(0.3480562, dtype=float32), Array(0.22358145, dtype=float32), Array(0.12927637, dtype=float32), Array(0.07455985, dtype=float32), Array(0.06344901, dtype=float32), Array(0.09448216, dtype=float32), Array(0.16454948, dtype=float32), Array(0.26241654, dtype=float32), Array(0.37815365, dtype=float32), Array(0.5022321, dtype=float32), Array(0.6124305, dtype=float32), Array(0.6916815, dtype=float32), Array(0.7297731, dtype=float32), Array(0.70556635, dtype=float32), Array(0.6467779, dtype=float32), Array(0.55940443, dtype=float32), Array(0.44662392, dtype=float32), Array(0.32479876, dtype=float32), Array(0.20678322, dtype=float32), Array(0.10859224, dtype=float32), Array(0.03985909, dtype=float32), Array(0.00672368, dtype=float32), Array(0.01343354, dtype=float32), Array(0.05837532, dtype=float32), Array(0.13606022, dtype=float32), Array(0.23732409, dtype=float32), Array(0.34747314, dtype=float32), Array(0.45211807, dtype=float32), Array(0.55171204, dtype=float32), Array(0.6351097, dtype=float32), Array(0.6812427, dtype=float32), Array(0.68571806, dtype=float32), Array(0.6630464, dtype=float32), Array(0.6074374, dtype=float32), Array(0.5340397, dtype=float32), Array(0.44992784, dtype=float32), Array(0.34327066, dtype=float32), Array(0.24539207, dtype=float32), Array(0.16416198, dtype=float32), Array(0.11107754, dtype=float32), Array(0.08996195, dtype=float32), Array(0.10296164, dtype=float32), Array(0.14568906, dtype=float32), Array(0.21170698, dtype=float32), Array(0.29262978, dtype=float32), Array(0.37794513, dtype=float32), Array(0.45719483, dtype=float32), Array(0.52001745, dtype=float32), Array(0.55769944, dtype=float32), Array(0.56495994, dtype=float32), Array(0.5407245, dtype=float32), Array(0.48823836, dtype=float32), Array(0.41638955, dtype=float32), Array(0.3330551, dtype=float32), Array(0.24684362, dtype=float32), Array(0.16721752, dtype=float32), Array(0.1019751, dtype=float32), Array(0.05901093, dtype=float32), Array(0.04073884, dtype=float32), Array(0.04880403, dtype=float32), Array(0.08172206, dtype=float32), Array(0.13424401, dtype=float32), Array(0.19350763, dtype=float32), Array(0.2533115, dtype=float32), Array(0.31131533, dtype=float32), Array(0.36383644, dtype=float32), Array(0.40363458, dtype=float32), Array(0.42214927, dtype=float32), Array(0.4130204, dtype=float32), Array(0.38769546, dtype=float32), Array(0.3400425, dtype=float32), Array(0.27931565, dtype=float32), Array(0.2110318, dtype=float32), Array(0.14373845, dtype=float32), Array(0.08504724, dtype=float32), Array(0.04043132, dtype=float32), Array(0.01401546, dtype=float32), Array(0.00856312, dtype=float32), Array(0.02425367, dtype=float32), Array(0.05715834, dtype=float32), Array(0.10263009, dtype=float32), Array(0.15638871, dtype=float32), Array(0.210733, dtype=float32), Array(0.25794208, dtype=float32), Array(0.2960255, dtype=float32), Array(0.3178128, dtype=float32), Array(0.31970224, dtype=float32), Array(0.30631953, dtype=float32), Array(0.27741912, dtype=float32), Array(0.23842005, dtype=float32), Array(0.19730644, dtype=float32), Array(0.15253004, dtype=float32), Array(0.10493547, dtype=float32), Array(0.06623366, dtype=float32), Array(0.04100164, dtype=float32), Array(0.03202339, dtype=float32), Array(0.03895631, dtype=float32), Array(0.05951374, dtype=float32), Array(0.09087119, dtype=float32), Array(0.12890634, dtype=float32), Array(0.16840634, dtype=float32), Array(0.20409788, dtype=float32), Array(0.23247628, dtype=float32), Array(0.24967617, dtype=float32), Array(0.2534997, dtype=float32), Array(0.24257018, dtype=float32), Array(0.21785368, dtype=float32), Array(0.18274513, dtype=float32), Array(0.14202882, dtype=float32), Array(0.1008494, dtype=float32), Array(0.06289809, dtype=float32), Array(0.03152255, dtype=float32), Array(0.01024386, dtype=float32), Array(0.00124356 ...
# [Array(0.86437094, dtype=float32), Array(0.8026799, dtype=float32), Array(0.7277153, dtype=float32), Array(0.6449497, dtype=float32), Array(0.55751264, dtype=float32), Array(0.47205314, dtype=float32), Array(0.39262068, dtype=float32), Array(0.3221594, dtype=float32), Array(0.26448083, dtype=float32), Array(0.22241852, dtype=float32), Array(0.19241245, dtype=float32), Array(0.180477, dtype=float32), Array(0.18215145, dtype=float32), Array(0.19458497, dtype=float32), Array(0.21603239, dtype=float32), Array(0.24783039, dtype=float32), Array(0.27893, dtype=float32), Array(0.30439162, dtype=float32), Array(0.3226782, dtype=float32), Array(0.332574, dtype=float32), Array(0.3183485, dtype=float32), Array(0.28361815, dtype=float32), Array(0.24211605, dtype=float32), Array(0.19266632, dtype=float32), Array(0.14558151, dtype=float32), Array(0.10342019, dtype=float32), Array(0.06784352, dtype=float32), Array(0.03885804, dtype=float32), Array(0.0173443, dtype=float32), Array(0.00432516, dtype=float32), Array(0.00116703, dtype=float32), Array(0.01175846, dtype=float32), Array(0.02862051, dtype=float32), Array(0.0431845, dtype=float32), Array(0.05466297, dtype=float32), Array(0.06499778, dtype=float32), Array(0.06767277, dtype=float32), Array(0.06892455, dtype=float32), Array(0.068512, dtype=float32), Array(0.06726437, dtype=float32), Array(0.06058973, dtype=float32), Array(0.05683331, dtype=float32), Array(0.05709833, dtype=float32), Array(0.06079438, dtype=float32), Array(0.06652145, dtype=float32), Array(0.07299128, dtype=float32), Array(0.07827116, dtype=float32), Array(0.08163708, dtype=float32), Array(0.08232055, dtype=float32), Array(0.08147075, dtype=float32), Array(0.07321672, dtype=float32), Array(0.061694, dtype=float32), Array(0.05051405, dtype=float32), Array(0.04117662, dtype=float32), Array(0.03486464, dtype=float32), Array(0.03031881, dtype=float32), Array(0.02600315, dtype=float32), Array(0.02119092, dtype=float32), Array(0.01657365, dtype=float32), Array(0.01243762, dtype=float32), Array(0.00610128, dtype=float32), Array(0.00104376, dtype=float32), Array(0.00142973, dtype=float32), Array(0.00609087, dtype=float32), Array(0.01233991, dtype=float32), Array(0.01907186, dtype=float32), Array(0.02620243, dtype=float32), Array(0.02937213, dtype=float32), Array(0.03190979, dtype=float32), Array(0.03451103, dtype=float32), Array(0.03747217, dtype=float32), Array(0.04433215, dtype=float32), Array(0.05303146, dtype=float32), Array(0.06173258, dtype=float32), Array(0.06930389, dtype=float32), Array(0.07523802, dtype=float32), Array(0.07933909, dtype=float32), Array(0.08147751, dtype=float32), Array(0.08156745, dtype=float32), Array(0.07997396, dtype=float32), Array(0.07335613, dtype=float32), Array(0.06496858, dtype=float32), Array(0.05691331, dtype=float32), Array(0.04929571, dtype=float32), Array(0.04177887, dtype=float32), Array(0.03554331, dtype=float32), Array(0.02880071, dtype=float32), Array(0.02161304, dtype=float32), Array(0.01385504, dtype=float32), Array(0.00759946, dtype=float32), Array(0.00254011, dtype=float32), Array(0.00238641, dtype=float32), Array(0.0065843, dtype=float32), Array(0.0124281, dtype=float32), Array(0.01963618, dtype=float32), Array(0.02610642, dtype=float32), Array(0.03443922, dtype=float32), Array(0.04378634, dtype=float32), Array(0.05320442, dtype=float32), Array(0.06222591, dtype=float32), Array(0.07317312, dtype=float32), Array(0.08306104, dtype=float32), Array(0.09134896, dtype=float32), Array(0.09697225, dtype=float32), Array(0.10199115, dtype=float32), Array(0.10414729, dtype=float32), Array(0.10567083, dtype=float32), Array(0.10669457, dtype=float32), Array(0.1056569, dtype=float32), Array(0.102861, dtype=float32), Array(0.09761428, dtype=float32), Array(0.08753822, dtype=float32), Array(0.07294004, dtype=float32), Array(0.05709339, dtype=float32), Array(0.0414339, dtype=float32), Array(0.02893773, dtype=float32), Array(0.01986579, dtype=float32), Array(0.01402186, dtype=float32), Array(0.0114 ...
# [Array(0.9044524, dtype=float32), Array(0.8633458, dtype=float32), Array(0.7860391, dtype=float32), Array(0.6804712, dtype=float32), Array(0.55817384, dtype=float32), Array(0.43235415, dtype=float32), Array(0.32073316, dtype=float32), Array(0.24216849, dtype=float32), Array(0.2130996, dtype=float32), Array(0.23477955, dtype=float32), Array(0.2987665, dtype=float32), Array(0.3875824, dtype=float32), Array(0.4805426, dtype=float32), Array(0.56184477, dtype=float32), Array(0.6214967, dtype=float32), Array(0.65006864, dtype=float32), Array(0.6434543, dtype=float32), Array(0.6008604, dtype=float32), Array(0.53216285, dtype=float32), Array(0.4367597, dtype=float32), Array(0.32485062, dtype=float32), Array(0.20877638, dtype=float32), Array(0.10529739, dtype=float32), Array(0.03647674, dtype=float32), Array(0.01644483, dtype=float32), Array(0.05506994, dtype=float32), Array(0.1331734, dtype=float32), Array(0.22801653, dtype=float32), Array(0.32125878, dtype=float32), Array(0.40342468, dtype=float32), Array(0.46090248, dtype=float32), Array(0.48719716, dtype=float32), Array(0.4802137, dtype=float32), Array(0.44215974, dtype=float32), Array(0.3819625, dtype=float32), Array(0.30306897, dtype=float32), Array(0.21716787, dtype=float32), Array(0.13910873, dtype=float32), Array(0.08848329, dtype=float32), Array(0.07632747, dtype=float32), Array(0.10523783, dtype=float32), Array(0.1639146, dtype=float32), Array(0.23289612, dtype=float32), Array(0.29717073, dtype=float32), Array(0.34592018, dtype=float32), Array(0.37241325, dtype=float32), Array(0.37373322, dtype=float32), Array(0.35084397, dtype=float32), Array(0.30799207, dtype=float32), Array(0.25329447, dtype=float32), Array(0.19790763, dtype=float32), Array(0.15542676, dtype=float32), Array(0.14032716, dtype=float32), Array(0.1536579, dtype=float32), Array(0.18913971, dtype=float32), Array(0.23564926, dtype=float32), Array(0.27907953, dtype=float32), Array(0.3083391, dtype=float32), Array(0.31737605, dtype=float32), Array(0.30476534, dtype=float32), Array(0.27119198, dtype=float32), Array(0.21903671, dtype=float32), Array(0.15651025, dtype=float32), Array(0.09475353, dtype=float32), Array(0.04933079, dtype=float32), Array(0.03129961, dtype=float32), Array(0.04349385, dtype=float32), Array(0.07518424, dtype=float32), Array(0.11115465, dtype=float32), Array(0.13998656, dtype=float32), Array(0.15453608, dtype=float32), Array(0.15133442, dtype=float32), Array(0.13275345, dtype=float32), Array(0.10113922, dtype=float32), Array(0.06471317, dtype=float32), Array(0.03356659, dtype=float32), Array(0.02152362, dtype=float32), Array(0.0307231, dtype=float32), Array(0.05655711, dtype=float32), Array(0.08591038, dtype=float32), Array(0.10921229, dtype=float32), Array(0.12069088, dtype=float32), Array(0.11904775, dtype=float32), Array(0.10634725, dtype=float32), Array(0.08797005, dtype=float32), Array(0.0727639, dtype=float32), Array(0.07224759, dtype=float32), Array(0.08757353, dtype=float32), Array(0.11290786, dtype=float32), Array(0.13910359, dtype=float32), Array(0.15690054, dtype=float32), Array(0.16771507, dtype=float32), Array(0.16288921, dtype=float32), Array(0.14221464, dtype=float32), Array(0.11019958, dtype=float32), Array(0.07196394, dtype=float32), Array(0.03749577, dtype=float32), Array(0.01989755, dtype=float32), Array(0.02488762, dtype=float32), Array(0.04106871, dtype=float32), Array(0.05699547, dtype=float32), Array(0.06509668, dtype=float32), Array(0.06222986, dtype=float32), Array(0.04874074, dtype=float32), Array(0.02848004, dtype=float32), Array(0.00947438, dtype=float32), Array(0.00118586, dtype=float32), Array(0.01204343, dtype=float32), Array(0.03306921, dtype=float32), Array(0.05314154, dtype=float32), Array(0.06547581, dtype=float32), Array(0.0665536, dtype=float32), Array(0.05741341, dtype=float32), Array(0.04213894, dtype=float32), Array(0.02837339, dtype=float32), Array(0.02469233, dtype=float32), Array(0.03554548, dtype=float32), Array(0.05701781, dtype=float32), Array(0. ...
# [Array(0.86437094, dtype=float32), Array(0.77544284, dtype=float32), Array(0.64254653, dtype=float32), Array(0.48371115, dtype=float32), Array(0.33196488, dtype=float32), Array(0.23190661, dtype=float32), Array(0.23424648, dtype=float32), Array(0.39050004, dtype=float32), Array(0.74706924, dtype=float32), Array(1.3109238, dtype=float32), Array(2.0225961, dtype=float32), Array(2.8239837, dtype=float32), Array(3.656587, dtype=float32), Array(4.4638677, dtype=float32), Array(5.1959186, dtype=float32), Array(5.8098207, dtype=float32), Array(6.2709937, dtype=float32), Array(6.564749, dtype=float32), Array(6.6727247, dtype=float32), Array(6.5888534, dtype=float32), Array(6.4275165, dtype=float32), Array(6.1679993, dtype=float32), Array(5.799556, dtype=float32), Array(5.3218126, dtype=float32), Array(4.745788, dtype=float32), Array(4.089804, dtype=float32), Array(3.3808155, dtype=float32), Array(2.6526759, dtype=float32), Array(1.9359717, dtype=float32), Array(1.2724556, dtype=float32), Array(0.73074967, dtype=float32), Array(0.32514045, dtype=float32), Array(0.08240097, dtype=float32), Array(0.03807084, dtype=float32), Array(0.22470719, dtype=float32), Array(0.6628745, dtype=float32), Array(1.3539722, dtype=float32), Array(2.2784839, dtype=float32), Array(3.3949041, dtype=float32), Array(4.6526475, dtype=float32), Array(6.029166, dtype=float32), Array(7.4709973, dtype=float32), Array(8.926909, dtype=float32), Array(10.348502, dtype=float32), Array(11.69294, dtype=float32), Array(12.919944, dtype=float32), Array(13.9946375, dtype=float32), Array(14.887869, dtype=float32), Array(15.577546, dtype=float32), Array(16.046066, dtype=float32), Array(16.414112, dtype=float32), Array(16.643805, dtype=float32), Array(16.709808, dtype=float32), Array(16.596626, dtype=float32), Array(16.297792, dtype=float32), Array(15.815768, dtype=float32), Array(15.15325, dtype=float32), Array(14.326744, dtype=float32), Array(13.347736, dtype=float32), Array(12.235796, dtype=float32), Array(11.10177, dtype=float32), Array(9.930453, dtype=float32), Array(8.722496, dtype=float32), Array(7.489191, dtype=float32), Array(6.250077, dtype=float32), Array(5.031484, dtype=float32), Array(3.8656526, dtype=float32), Array(2.7901146, dtype=float32), Array(1.8443937, dtype=float32), Array(1.068457, dtype=float32), Array(0.5149199, dtype=float32), Array(0.19967647, dtype=float32), Array(0.14997318, dtype=float32), Array(0.3951887, dtype=float32), Array(0.944207, dtype=float32), Array(1.7753403, dtype=float32), Array(2.8477063, dtype=float32), Array(4.1148324, dtype=float32), Array(5.524963, dtype=float32), Array(7.028247, dtype=float32), Array(8.630139, dtype=float32), Array(10.281275, dtype=float32), Array(11.934519, dtype=float32), Array(13.545285, dtype=float32), Array(15.07254, dtype=float32), Array(16.47945, dtype=float32), Array(17.733776, dtype=float32), Array(18.80998, dtype=float32), Array(19.685417, dtype=float32), Array(20.35003, dtype=float32), Array(20.912514, dtype=float32), Array(21.334873, dtype=float32), Array(21.588589, dtype=float32), Array(21.65849, dtype=float32), Array(21.533537, dtype=float32), Array(21.214731, dtype=float32), Array(20.703941, dtype=float32), Array(20.01255, dtype=float32), Array(19.146524, dtype=float32), Array(18.119043, dtype=float32), Array(17.034687, dtype=float32), Array(15.872017, dtype=float32), Array(14.62378, dtype=float32), Array(13.294378, dtype=float32), Array(11.895308, dtype=float32), Array(10.448867, dtype=float32), Array(8.977213, dtype=float32), Array(7.512667, dtype=float32), Array(6.0848875, dtype=float32), Array(4.727691, dtype=float32), Array(3.5154874, dtype=float32), Array(2.453473, dtype=float32), Array(1.5594101, dtype=float32), Array(0.85892, dtype=float32), Array(0.3850551, dtype=float32), Array(0.1728673, dtype=float32), Array(0.25608757, dtype=float32), Array(0.66232896, dtype=float32), Array(1.4078451, dtype=float32), Array(2.492407, dtype=float32), Array(3.8547235, dtype=float32), Array(5.4399834, dtyp ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3d717f43-f565-4198-bc5d-42467675cd81' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
